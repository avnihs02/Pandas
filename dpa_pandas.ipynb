# %%
import pandas as pd

# %%
iris = pd.read_csv(r"D:\download\iris\Iris.csv")

# %%
iris = pd.DataFrame(iris)
iris.info
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# ### axes returns list of rows and index and type

# %%
print(iris.axes)
type(iris.axes)
# Out:
# [RangeIndex(start=0, stop=150, step=1), Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')]
# list

# %% [markdown]
# ### describe() returns count, mean, std, min, quartile and max

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### values returns numpy array of values inside dataframe

# %%
iris.values
type(iris.values)
# Out:
# numpy.ndarray

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# ### Filter dataframe by colnames

# %%
iris.filter(items = ['SepalLengthCm','PetalWidthCm'])
# Out:
#      SepalLengthCm  PetalWidthCm
# 0              5.1           0.2
# 1              4.9           0.2
# 2              4.7           0.2
# 3              4.6           0.2
# 4              5.0           0.2
# ..             ...           ...
# 145            6.7           2.3
# 146            6.3           1.9
# 147            6.5           2.0
# 148            6.2           2.3
# 149            5.9           1.8
#
# [150 rows x 2 columns]

# %%
for x in iris.__iter__():
    print(x)
# Out:
# Id
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Species

# %%
for x,y in iris.items():
    print(x,y)
# Out:
# Id 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64
# SepalLengthCm 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64
# SepalWidthCm 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64
# PetalLengthCm 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64
# PetalWidthCm 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# ...

# %%
weather = pd.read_csv(r"E:\downloads\6883_9923_bundle_archive\weather.csv")

# %%
weather['RainToday']
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 361     No
# 362     No
# 363     No
# 364     No
# 365     No
# Name: RainToday, Length: 366, dtype: object

# %% [markdown]
# ### pivot and pivot_table

# %%
weather.axes
# Out:
# [RangeIndex(start=0, stop=366, step=1),
#  Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#         'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#         'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#         'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#         'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#        dtype='object')]

# %%
weather.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.pivot_table(index = 'WindGustDir', columns = ['RainToday','RainTomorrow'], values = 'Humidity3pm')
# Out:
# RainToday            No                   Yes
# RainTomorrow         No        Yes         No   Yes
# WindGustDir
# E             40.300000  45.000000  42.000000   NaN
# ENE           41.640000        NaN  60.000000  56.0
# ESE           44.000000  48.750000  63.333333  49.5
# N             38.333333  62.000000  62.000000  48.0
# NE            36.583333  44.000000  42.000000  88.0
# NNE           45.666667  65.000000  46.000000   NaN
# NNW           35.857143  49.571429  46.000000  67.4
# NW            37.577778  50.818182  55.916667  67.4
# S             39.307692  60.000000  40.800000  71.0
# SE            51.000000        NaN        NaN   NaN
# SSE           31.833333  72.000000  54.333333  90.0
# SSW           30.666667  61.500000        NaN   NaN
# SW            49.000000  51.000000        NaN   NaN
# W             36.777778  66.800000  59.500000  58.0
# WNW           43.464286  59.500000  44.000000   NaN
# WSW           26.000000        NaN        NaN   NaN

# %%
weather.pivot_table(index = 'WindGustDir',\
                    columns = ['RainToday','RainTomorrow'], values = 'Humidity3pm'\
                   ,aggfunc = 'sum')
pd.pivot_table(weather, index = 'WindGustDir',\
                    columns = ['RainToday','RainTomorrow'], values = 'Humidity3pm'\
                   ,aggfunc = 'sum')
# Out:
# RainToday         No           Yes
# RainTomorrow      No    Yes     No    Yes
# WindGustDir
# E             1209.0  180.0  126.0    NaN
# ENE           1041.0    NaN  180.0  112.0
# ESE            616.0  195.0  190.0   99.0
# N              690.0   62.0   62.0   48.0
# NE             439.0   88.0   42.0   88.0
# NNE            274.0   65.0   46.0    NaN
# NNW           1004.0  347.0  184.0  337.0
# NW            1691.0  559.0  671.0  337.0
# S              511.0  120.0  204.0  142.0
# SE             612.0    NaN    NaN    NaN
# SSE            191.0  144.0  163.0   90.0
# SSW             92.0  123.0    NaN    NaN
# SW              49.0  102.0    NaN    NaN
# W              331.0  334.0  238.0  116.0
# WNW           1217.0  119.0  220.0    NaN
# WSW             52.0    NaN    NaN    NaN

# %%
iris.head()
df1 = pd.melt(iris, id_vars = 'Species', value_vars = 'PetalLengthCm',var_name = 'Type',\
        value_name = 'Length')
df1
# Out:
#             Species           Type  Length
# 0       Iris-setosa  PetalLengthCm     1.4
# 1       Iris-setosa  PetalLengthCm     1.4
# 2       Iris-setosa  PetalLengthCm     1.3
# 3       Iris-setosa  PetalLengthCm     1.5
# 4       Iris-setosa  PetalLengthCm     1.4
# ..              ...            ...     ...
# 145  Iris-virginica  PetalLengthCm     5.2
# 146  Iris-virginica  PetalLengthCm     5.0
# 147  Iris-virginica  PetalLengthCm     5.2
# 148  Iris-virginica  PetalLengthCm     5.4
# 149  Iris-virginica  PetalLengthCm     5.1
#
# [150 rows x 3 columns]

# %%
df1[df1['Length'] == 1.4]
# Out:
#         Species           Type  Length
# 0   Iris-setosa  PetalLengthCm     1.4
# 1   Iris-setosa  PetalLengthCm     1.4
# 4   Iris-setosa  PetalLengthCm     1.4
# 6   Iris-setosa  PetalLengthCm     1.4
# 8   Iris-setosa  PetalLengthCm     1.4
# 12  Iris-setosa  PetalLengthCm     1.4
# 17  Iris-setosa  PetalLengthCm     1.4
# 28  Iris-setosa  PetalLengthCm     1.4
# 33  Iris-setosa  PetalLengthCm     1.4
# 45  Iris-setosa  PetalLengthCm     1.4
# 47  Iris-setosa  PetalLengthCm     1.4
# 49  Iris-setosa  PetalLengthCm     1.4

# %%
for i,j in iris.iterrows():
    
    print(i,j)
# Out:
# 0 Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object
# 1 Id                         2
# SepalLengthCm            4.9
# SepalWidthCm               3
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 1, dtype: object
# 2 Id                         3
# SepalLengthCm            4.7
# SepalWidthCm             3.2
# PetalLengthCm            1.3
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 2, dtype: object
# 3 Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object
# 4 Id                         5
# SepalLengthCm              5
# SepalWidthCm             3.6
# PetalLengthCm            1.4
# ...

# %% [markdown]
# ### loc iloc

# %%
iris.loc[iris['SepalLengthCm'] == 4.6]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
